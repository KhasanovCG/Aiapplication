# %% [markdown]
# <a href="https://colab.research.google.com/github/KhasanovCG/Aiapplication/blob/main/chapter9_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import SimpleRNN
import logging
tf.get_logger().setLevel(logging.ERROR)
EPOCHS = 100
BATCH_SIZE = 16
TRAIN_TEST_SPLIT = 0.8
MIN = 12
FILE_NAME = 'book_store_sales.csv'
def readfile(file_name):
  file = open(file_name, 'r', encoding='utf-8')
  next(file)
  data = []
  for line in (file):
    values = line.split(',')
    data.append(float(values[1]))
  file.close()
  return np.array(data, dtype=np.float32)
# Read data and split into training and test data.
sales = readfile(FILE_NAME)
months = len(sales)
split = int(months * TRAIN_TEST_SPLIT)
train_sales = sales[0:split]
test_sales = sales[split:]

# %%
# Plot dataset
x = range(len(sales))
plt.plot(x, sales, 'r-', label='book sales')
plt.title('Book store sales')
plt.axis([0, 339, 0.0, 3000.0])
plt.xlabel('Months')
plt.ylabel('Sales (millions $)')
plt.legend()
plt.show()

# %%
# Plot naive prediction
test_output = test_sales[MIN:]
naive_prediction = test_sales[MIN-1:-1]
x = range(len(test_output))
plt.plot(x, test_output, 'g-', label='test_output')
plt.plot(x, naive_prediction, 'm-', label='naive prediction')
plt.title('Book store sales')
plt.axis([0, len(test_output), 0.0, 3000.0])
plt.xlabel('months')
plt.ylabel('Monthly book store sales')
plt.legend()
plt.show()

# %%
# Standardize train and test data.
# Use only training seasons to compute mean and stddev.
mean = np.mean(train_sales)
stddev = np.std(train_sales)
train_sales_std = (train_sales - mean)/stddev
test_sales_std = (test_sales - mean)/stddev

# %%
 # Create training examples.
train_months = len(train_sales)
train_X = np.zeros((train_months-MIN, train_months-1, 1))
train_y = np.zeros((train_months-MIN, 1))
for i in range(0, train_months-MIN):
  train_X[i, -(i+MIN):, 0] = train_sales_std[0:i+MIN]
  train_y[i, 0] = train_sales_std[i+MIN]
# Create test examples.
test_months = len(test_sales)
test_X = np.zeros((test_months-MIN, test_months-1, 1))
test_y = np.zeros((test_months-MIN, 1))
for i in range(0, test_months-MIN):
  test_X[i, -(i+MIN):, 0] = test_sales_std[0:i+MIN]
  test_y[i, 0] = test_sales_std[i+MIN]

# %%
# Create RNN model
model = Sequential()
model.add(SimpleRNN(128, activation='relu',input_shape=(None, 1)))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam',metrics =['mean_absolute_error'])
model.summary()
history = model.fit(train_X, train_y,validation_data= (test_X, test_y), epochs=EPOCHS,batch_size=BATCH_SIZE, verbose=2,shuffle=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 128)               16640
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 16769 (65.50 KB)
# Trainable params: 16769 (65.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 17/17 - 3s - loss: 0.8260 - mean_absolute_error: 0.6890 - val_loss: 0.5985 - val_mean_absolute_error: 0.6863 - 3s/epoch - 200ms/step
# Epoch 2/100
# 17/17 - 1s - loss: 0.4333 - mean_absolute_error: 0.5023 - val_loss: 0.2215 - val_mean_absolute_error: 0.3166 - 819ms/epoch - 48ms/step
# Epoch 3/100
# 17/17 - 1s - loss: 0.1504 - mean_absolute_error: 0.2895 - val_loss: 0.1491 - val_mean_absolute_error: 0.2640 - 821ms/epoch - 48ms/step
# Epoch 4/100
# 17/17 - 1s - loss: 0.0880 - mean_absolute_error: 0.2313 - val_loss: 0.0874 - val_mean_absolute_error: 0.1754 - 820ms/epoch - 48ms/step
# Epoch 5/100
# 17/17 - 1s - loss: 0.0696 - mean_absolute_error: 0.1919 - val_loss: 0.1301 - val_mean_absolute_error: 0.2727 - 863ms/epoch - 51ms/step
# Epoch 6/100
# 17/17 - 1s - loss: 0.0768 - mean_absolute_error: 0.2202 - val_loss: 0.0638 - val_mean_absolute_error: 0.1821 - 810ms/epoch - 48ms/step
# Epoch 7/100
# 17/17 - 1s - loss: 0.0615 - mean_absolute_error: 0.1985 - val_loss: 0.0566 - val_mean_absolute_error: 0.1466 - 825ms/epoch - 49ms/step
# Epoch 8/100
# 17/17 - 1s - loss: 0.0469 - mean_absolute_error: 0.1601 - val_loss: 0.0580 - val_mean_absolute_error: 0.1530 - 816ms/epoch - 48ms/step
# Epoch 9/100
# 17/17 - 1s - loss: 0.0401 - mean_absolute_error: 0.1515 - val_loss: 0.0537 - val_mean_absolute_error: 0.1656 - 832ms/epoch - 49ms/step
# Epoch 10/100
# 17/17 - 1s - loss: 0.0378 - mean_absolute_error: 0.1497 - val_loss: 0.0830 - val_mean_absolute_error: 0.1885 - 836ms/epoch - 49ms/step
# Epoch 11/100
# 17/17 - 1s - loss: 0.0381 - mean_absolute_error: 0.1499 - val_loss: 0.0571 - val_mean_absolute_error: 0.1691 - 829ms/epoch - 49ms/step
# Epoch 12/100
# 17/17 - 1s - loss: 0.0322 - mean_absolute_error: 0.1299 - val_loss: 0.0520 - val_mean_absolute_error: 0.1567 - 808ms/epoch - 48ms/step
# Epoch 13/100
# 17/17 - 1s - loss: 0.0409 - mean_absolute_error: 0.1454 - val_loss: 0.0519 - val_mean_absolute_error: 0.1611 - 1s/epoch - 70ms/step
# Epoch 14/100
# 17/17 - 2s - loss: 0.0292 - mean_absolute_error: 0.1306 - val_loss: 0.0633 - val_mean_absolute_error: 0.1846 - 2s/epoch - 93ms/step
# Epoch 15/100
# 17/17 - 1s - loss: 0.0254 - mean_absolute_error: 0.1177 - val_loss: 0.0385 - val_mean_absolute_error: 0.1381 - 1s/epoch - 68ms/step
# Epoch 16/100
# 17/17 - 1s - loss: 0.0352 - mean_absolute_error: 0.1433 - val_loss: 0.0509 - val_mean_absolute_error: 0.1671 - 862ms/epoch - 51ms/step
# Epoch 17/100
# 17/17 - 1s - loss: 0.0307 - mean_absolute_error: 0.1396 - val_loss: 0.0775 - val_mean_absolute_error: 0.2015 - 835ms/epoch - 49ms/step
# Epoch 18/100
# 17/17 - 1s - loss: 0.0306 - mean_absolute_error: 0.1313 - val_loss: 0.0454 - val_mean_absolute_error: 0.1543 - 829ms/epoch - 49ms/step
# Epoch 19/100
# 17/17 - 1s - loss: 0.0304 - mean_absolute_error: 0.1375 - val_loss: 0.0647 - val_mean_absolute_error: 0.1760 - 851ms/epoch - 50ms/step
# Epoch 20/100
# 17/17 - 1s - loss: 0.0303 - mean_absolute_error: 0.1364 - val_loss: 0.0488 - val_mean_absolute_error: 0.1698 - 789ms/epoch - 46ms/step
# Epoch 21/100
# 17/17 - 1s - loss: 0.0222 - mean_absolute_error: 0.1148 - val_loss: 0.0407 - val_mean_absolute_error: 0.1401 - 831ms/epoch - 49ms/step
# Epoch 22/100
# 17/17 - 1s - loss: 0.0212 - mean_absolute_error: 0.1101 - val_loss: 0.0374 - val_mean_absolute_error: 0.1340 - 806ms/epoch - 47ms/step
# Epoch 23/100
# 17/17 - 1s - loss: 0.0204 - mean_absolute_error: 0.1103 - val_loss: 0.0390 - val_mean_absolute_error: 0.1336 - 832ms/epoch - 49ms/step
# Epoch 24/100
# 17/17 - 1s - loss: 0.0166 - mean_absolute_error: 0.0968 - val_loss: 0.0482 - val_mean_absolute_error: 0.1513 - 825ms/epoch - 49ms/step
# Epoch 25/100
# 17/17 - 1s - loss: 0.0202 - mean_absolute_error: 0.1040 - val_loss: 0.0489 - val_mean_absolute_error: 0.1541 - 860ms/epoch - 51ms/step
# Epoch 26/100
# 17/17 - 1s - loss: 0.0182 - mean_absolute_error: 0.0982 - val_loss: 0.0297 - val_mean_absolute_error: 0.1220 - 859ms/epoch - 51ms/step
# Epoch 27/100
# 17/17 - 1s - loss: 0.0189 - mean_absolute_error: 0.1091 - val_loss: 0.0592 - val_mean_absolute_error: 0.1785 - 1s/epoch - 88ms/step
# Epoch 28/100
# 17/17 - 2s - loss: 0.0168 - mean_absolute_error: 0.0943 - val_loss: 0.0355 - val_mean_absolute_error: 0.1209 - 2s/epoch - 97ms/step
# Epoch 29/100
# 17/17 - 1s - loss: 0.0292 - mean_absolute_error: 0.1232 - val_loss: 0.0555 - val_mean_absolute_error: 0.1750 - 881ms/epoch - 52ms/step
# Epoch 30/100
# 17/17 - 1s - loss: 0.0228 - mean_absolute_error: 0.1161 - val_loss: 0.0442 - val_mean_absolute_error: 0.1418 - 913ms/epoch - 54ms/step
# Epoch 31/100
# 17/17 - 1s - loss: 0.0205 - mean_absolute_error: 0.1074 - val_loss: 0.0435 - val_mean_absolute_error: 0.1444 - 807ms/epoch - 47ms/step
# Epoch 32/100
# 17/17 - 1s - loss: 0.0152 - mean_absolute_error: 0.0930 - val_loss: 0.0387 - val_mean_absolute_error: 0.1288 - 826ms/epoch - 49ms/step
# Epoch 33/100
# 17/17 - 1s - loss: 0.0140 - mean_absolute_error: 0.0898 - val_loss: 0.0330 - val_mean_absolute_error: 0.1215 - 810ms/epoch - 48ms/step
# Epoch 34/100
# 17/17 - 1s - loss: 0.0142 - mean_absolute_error: 0.0894 - val_loss: 0.0574 - val_mean_absolute_error: 0.1701 - 861ms/epoch - 51ms/step
# Epoch 35/100
# 17/17 - 1s - loss: 0.0150 - mean_absolute_error: 0.0900 - val_loss: 0.0280 - val_mean_absolute_error: 0.1084 - 806ms/epoch - 47ms/step
# Epoch 36/100
# 17/17 - 1s - loss: 0.0152 - mean_absolute_error: 0.0892 - val_loss: 0.0465 - val_mean_absolute_error: 0.1466 - 854ms/epoch - 50ms/step
# Epoch 37/100
# 17/17 - 1s - loss: 0.0134 - mean_absolute_error: 0.0864 - val_loss: 0.0373 - val_mean_absolute_error: 0.1264 - 832ms/epoch - 49ms/step
# Epoch 38/100
# 17/17 - 1s - loss: 0.0160 - mean_absolute_error: 0.0919 - val_loss: 0.0421 - val_mean_absolute_error: 0.1407 - 825ms/epoch - 49ms/step
# Epoch 39/100
# 17/17 - 1s - loss: 0.0202 - mean_absolute_error: 0.1086 - val_loss: 0.0740 - val_mean_absolute_error: 0.2098 - 857ms/epoch - 50ms/step
# Epoch 40/100
# 17/17 - 1s - loss: 0.0173 - mean_absolute_error: 0.1009 - val_loss: 0.0432 - val_mean_absolute_error: 0.1517 - 1s/epoch - 60ms/step
# Epoch 41/100
# 17/17 - 2s - loss: 0.0141 - mean_absolute_error: 0.0896 - val_loss: 0.0645 - val_mean_absolute_error: 0.1726 - 2s/epoch - 97ms/step
# Epoch 42/100
# 17/17 - 1s - loss: 0.0161 - mean_absolute_error: 0.0921 - val_loss: 0.0341 - val_mean_absolute_error: 0.1229 - 1s/epoch - 71ms/step
# Epoch 43/100
# 17/17 - 1s - loss: 0.0156 - mean_absolute_error: 0.0974 - val_loss: 0.0337 - val_mean_absolute_error: 0.1205 - 905ms/epoch - 53ms/step
# Epoch 44/100
# 17/17 - 1s - loss: 0.0245 - mean_absolute_error: 0.1156 - val_loss: 0.0344 - val_mean_absolute_error: 0.1272 - 821ms/epoch - 48ms/step
# Epoch 45/100
# 17/17 - 1s - loss: 0.0273 - mean_absolute_error: 0.1248 - val_loss: 0.0529 - val_mean_absolute_error: 0.1710 - 894ms/epoch - 53ms/step
# Epoch 46/100
# 17/17 - 1s - loss: 0.0177 - mean_absolute_error: 0.1001 - val_loss: 0.0494 - val_mean_absolute_error: 0.1590 - 883ms/epoch - 52ms/step
# Epoch 47/100
# 17/17 - 1s - loss: 0.0153 - mean_absolute_error: 0.0934 - val_loss: 0.0523 - val_mean_absolute_error: 0.1645 - 802ms/epoch - 47ms/step
# Epoch 48/100
# 17/17 - 1s - loss: 0.0115 - mean_absolute_error: 0.0797 - val_loss: 0.0321 - val_mean_absolute_error: 0.1192 - 853ms/epoch - 50ms/step
# Epoch 49/100
# 17/17 - 1s - loss: 0.0122 - mean_absolute_error: 0.0844 - val_loss: 0.0475 - val_mean_absolute_error: 0.1497 - 805ms/epoch - 47ms/step
# Epoch 50/100
# 17/17 - 1s - loss: 0.0117 - mean_absolute_error: 0.0819 - val_loss: 0.0305 - val_mean_absolute_error: 0.1186 - 873ms/epoch - 51ms/step
# Epoch 51/100
# 17/17 - 1s - loss: 0.0108 - mean_absolute_error: 0.0768 - val_loss: 0.0320 - val_mean_absolute_error: 0.1166 - 834ms/epoch - 49ms/step
# Epoch 52/100
# 17/17 - 1s - loss: 0.0105 - mean_absolute_error: 0.0734 - val_loss: 0.0348 - val_mean_absolute_error: 0.1221 - 833ms/epoch - 49ms/step
# Epoch 53/100
# 17/17 - 1s - loss: 0.0114 - mean_absolute_error: 0.0784 - val_loss: 0.0391 - val_mean_absolute_error: 0.1359 - 835ms/epoch - 49ms/step
# Epoch 54/100
# 17/17 - 1s - loss: 0.0148 - mean_absolute_error: 0.0880 - val_loss: 0.0317 - val_mean_absolute_error: 0.1279 - 1s/epoch - 85ms/step
# Epoch 55/100
# 17/17 - 2s - loss: 0.0154 - mean_absolute_error: 0.0940 - val_loss: 0.0327 - val_mean_absolute_error: 0.1204 - 2s/epoch - 90ms/step
# Epoch 56/100
# 17/17 - 1s - loss: 0.0141 - mean_absolute_error: 0.0862 - val_loss: 0.0503 - val_mean_absolute_error: 0.1626 - 913ms/epoch - 54ms/step
# Epoch 57/100
# 17/17 - 1s - loss: 0.0197 - mean_absolute_error: 0.0990 - val_loss: 0.0513 - val_mean_absolute_error: 0.1564 - 834ms/epoch - 49ms/step
# Epoch 58/100
# 17/17 - 1s - loss: 0.0256 - mean_absolute_error: 0.1137 - val_loss: 0.0468 - val_mean_absolute_error: 0.1523 - 851ms/epoch - 50ms/step
# Epoch 59/100
# 17/17 - 1s - loss: 0.0258 - mean_absolute_error: 0.1157 - val_loss: 0.0437 - val_mean_absolute_error: 0.1380 - 848ms/epoch - 50ms/step
# Epoch 60/100
# 17/17 - 1s - loss: 0.0160 - mean_absolute_error: 0.0918 - val_loss: 0.0425 - val_mean_absolute_error: 0.1496 - 798ms/epoch - 47ms/step
# Epoch 61/100
# 17/17 - 1s - loss: 0.0134 - mean_absolute_error: 0.0887 - val_loss: 0.0351 - val_mean_absolute_error: 0.1204 - 865ms/epoch - 51ms/step
# Epoch 62/100
# 17/17 - 1s - loss: 0.0152 - mean_absolute_error: 0.0938 - val_loss: 0.0358 - val_mean_absolute_error: 0.1327 - 834ms/epoch - 49ms/step
# Epoch 63/100
# 17/17 - 1s - loss: 0.0121 - mean_absolute_error: 0.0847 - val_loss: 0.0373 - val_mean_absolute_error: 0.1309 - 807ms/epoch - 47ms/step
# Epoch 64/100
# 17/17 - 1s - loss: 0.0144 - mean_absolute_error: 0.0962 - val_loss: 0.0345 - val_mean_absolute_error: 0.1218 - 829ms/epoch - 49ms/step
# Epoch 65/100
# 17/17 - 1s - loss: 0.0134 - mean_absolute_error: 0.0866 - val_loss: 0.0434 - val_mean_absolute_error: 0.1491 - 797ms/epoch - 47ms/step
# Epoch 66/100
# 17/17 - 1s - loss: 0.0128 - mean_absolute_error: 0.0849 - val_loss: 0.0437 - val_mean_absolute_error: 0.1446 - 866ms/epoch - 51ms/step
# Epoch 67/100
# 17/17 - 1s - loss: 0.0142 - mean_absolute_error: 0.0849 - val_loss: 0.0420 - val_mean_absolute_error: 0.1447 - 888ms/epoch - 52ms/step
# Epoch 68/100
# 17/17 - 2s - loss: 0.0082 - mean_absolute_error: 0.0680 - val_loss: 0.0433 - val_mean_absolute_error: 0.1471 - 2s/epoch - 92ms/step
# Epoch 69/100
# 17/17 - 1s - loss: 0.0112 - mean_absolute_error: 0.0810 - val_loss: 0.0388 - val_mean_absolute_error: 0.1369 - 1s/epoch - 85ms/step
# Epoch 70/100
# 17/17 - 1s - loss: 0.0136 - mean_absolute_error: 0.0838 - val_loss: 0.0663 - val_mean_absolute_error: 0.1737 - 851ms/epoch - 50ms/step
# Epoch 71/100
# 17/17 - 1s - loss: 0.0296 - mean_absolute_error: 0.1258 - val_loss: 0.0462 - val_mean_absolute_error: 0.1475 - 844ms/epoch - 50ms/step
# Epoch 72/100
# 17/17 - 1s - loss: 0.0294 - mean_absolute_error: 0.1232 - val_loss: 0.0469 - val_mean_absolute_error: 0.1455 - 825ms/epoch - 49ms/step
# Epoch 73/100
# 17/17 - 1s - loss: 0.0192 - mean_absolute_error: 0.1031 - val_loss: 0.0372 - val_mean_absolute_error: 0.1333 - 826ms/epoch - 49ms/step
# Epoch 74/100
# 17/17 - 1s - loss: 0.0260 - mean_absolute_error: 0.1159 - val_loss: 0.1011 - val_mean_absolute_error: 0.2606 - 831ms/epoch - 49ms/step
# Epoch 75/100
# 17/17 - 1s - loss: 0.0223 - mean_absolute_error: 0.1224 - val_loss: 0.0502 - val_mean_absolute_error: 0.1546 - 1s/epoch - 70ms/step
# Epoch 76/100
# 17/17 - 1s - loss: 0.0160 - mean_absolute_error: 0.0968 - val_loss: 0.0562 - val_mean_absolute_error: 0.1754 - 1s/epoch - 73ms/step
# Epoch 77/100
# 17/17 - 1s - loss: 0.0140 - mean_absolute_error: 0.0895 - val_loss: 0.0498 - val_mean_absolute_error: 0.1595 - 826ms/epoch - 49ms/step
# Epoch 78/100
# 17/17 - 1s - loss: 0.0151 - mean_absolute_error: 0.0911 - val_loss: 0.0557 - val_mean_absolute_error: 0.1649 - 873ms/epoch - 51ms/step
# Epoch 79/100
# 17/17 - 1s - loss: 0.0123 - mean_absolute_error: 0.0806 - val_loss: 0.0449 - val_mean_absolute_error: 0.1524 - 856ms/epoch - 50ms/step
# Epoch 80/100
# 17/17 - 1s - loss: 0.0098 - mean_absolute_error: 0.0763 - val_loss: 0.0308 - val_mean_absolute_error: 0.1262 - 975ms/epoch - 57ms/step
# Epoch 81/100
# 17/17 - 2s - loss: 0.0140 - mean_absolute_error: 0.0809 - val_loss: 0.0393 - val_mean_absolute_error: 0.1363 - 2s/epoch - 94ms/step
# Epoch 82/100
# 17/17 - 1s - loss: 0.0144 - mean_absolute_error: 0.0943 - val_loss: 0.0390 - val_mean_absolute_error: 0.1424 - 1s/epoch - 76ms/step
# Epoch 83/100
# 17/17 - 1s - loss: 0.0098 - mean_absolute_error: 0.0754 - val_loss: 0.0459 - val_mean_absolute_error: 0.1584 - 826ms/epoch - 49ms/step
# Epoch 84/100
# 17/17 - 1s - loss: 0.0093 - mean_absolute_error: 0.0722 - val_loss: 0.0424 - val_mean_absolute_error: 0.1494 - 1s/epoch - 66ms/step
# Epoch 85/100
# 17/17 - 1s - loss: 0.0072 - mean_absolute_error: 0.0622 - val_loss: 0.0398 - val_mean_absolute_error: 0.1391 - 860ms/epoch - 51ms/step
# Epoch 86/100
# 17/17 - 1s - loss: 0.0065 - mean_absolute_error: 0.0606 - val_loss: 0.0401 - val_mean_absolute_error: 0.1427 - 804ms/epoch - 47ms/step
# Epoch 87/100
# 17/17 - 1s - loss: 0.0073 - mean_absolute_error: 0.0622 - val_loss: 0.0344 - val_mean_absolute_error: 0.1306 - 826ms/epoch - 49ms/step
# Epoch 88/100
# 17/17 - 1s - loss: 0.0068 - mean_absolute_error: 0.0614 - val_loss: 0.0399 - val_mean_absolute_error: 0.1403 - 813ms/epoch - 48ms/step
# Epoch 89/100
# 17/17 - 1s - loss: 0.0061 - mean_absolute_error: 0.0589 - val_loss: 0.0383 - val_mean_absolute_error: 0.1366 - 862ms/epoch - 51ms/step
# Epoch 90/100
# 17/17 - 1s - loss: 0.0073 - mean_absolute_error: 0.0625 - val_loss: 0.0410 - val_mean_absolute_error: 0.1460 - 855ms/epoch - 50ms/step
# Epoch 91/100
# 17/17 - 1s - loss: 0.0092 - mean_absolute_error: 0.0715 - val_loss: 0.0291 - val_mean_absolute_error: 0.1131 - 832ms/epoch - 49ms/step
# Epoch 92/100
# 17/17 - 1s - loss: 0.0086 - mean_absolute_error: 0.0683 - val_loss: 0.0475 - val_mean_absolute_error: 0.1506 - 859ms/epoch - 51ms/step
# Epoch 93/100
# 17/17 - 1s - loss: 0.0089 - mean_absolute_error: 0.0696 - val_loss: 0.0336 - val_mean_absolute_error: 0.1225 - 862ms/epoch - 51ms/step
# Epoch 94/100
# 17/17 - 2s - loss: 0.0076 - mean_absolute_error: 0.0647 - val_loss: 0.0412 - val_mean_absolute_error: 0.1416 - 2s/epoch - 89ms/step
# Epoch 95/100
# 17/17 - 2s - loss: 0.0077 - mean_absolute_error: 0.0657 - val_loss: 0.0284 - val_mean_absolute_error: 0.1149 - 2s/epoch - 94ms/step
# Epoch 96/100
# 17/17 - 1s - loss: 0.0076 - mean_absolute_error: 0.0671 - val_loss: 0.0424 - val_mean_absolute_error: 0.1497 - 839ms/epoch - 49ms/step
# Epoch 97/100
# 17/17 - 1s - loss: 0.0112 - mean_absolute_error: 0.0839 - val_loss: 0.0376 - val_mean_absolute_error: 0.1369 - 906ms/epoch - 53ms/step
# Epoch 98/100
# 17/17 - 1s - loss: 0.0083 - mean_absolute_error: 0.0681 - val_loss: 0.0579 - val_mean_absolute_error: 0.1777 - 822ms/epoch - 48ms/step
# Epoch 99/100
# 17/17 - 1s - loss: 0.0081 - mean_absolute_error: 0.0694 - val_loss: 0.0324 - val_mean_absolute_error: 0.1248 - 829ms/epoch - 49ms/step
# Epoch 100/100
# 17/17 - 1s - loss: 0.0078 - mean_absolute_error: 0.0666 - val_loss: 0.0453 - val_mean_absolute_error: 0.1544 - 840ms/epoch - 49ms/step

# %%
# Create naive prediction based on standardized data.
test_output = test_sales_std[MIN:]
naive_prediction = test_sales_std[MIN-1:-1]
mean_squared_error = np.mean(np.square(naive_prediction
- test_output))
mean_abs_error = np.mean(np.abs(naive_prediction- test_output))
print('naive test mse: ', mean_squared_error)
print('naive test mean abs: ', mean_abs_error)
# Out:
# naive test mse:  0.4723033
# naive test mean abs:  0.48052385

# %%
# Use trained model to predict the test data
predicted_test = model.predict(test_X, len(test_X))
predicted_test = np.reshape(predicted_test,(len(predicted_test)))
predicted_test = predicted_test * stddev + mean
# Plot test prediction.
x = range(len(test_sales)-MIN)
plt.plot(x, predicted_test, 'm-',label='predicted test_output')
plt.plot(x, test_sales[-(len(test_sales)-MIN):],'g-', label='actual test_output')
plt.title('Book sales')
plt.axis([0, 55, 0.0, 3000.0])
plt.xlabel('months')
plt.ylabel('Predicted book sales')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 169ms/step
